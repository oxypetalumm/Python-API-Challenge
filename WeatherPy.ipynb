# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List to hold lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %%
# start api calls
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # append data
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # skip the cities that are not found
    except:
        print("City not found. Skipping...")
        pass
              
# indicate completion of data loading
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | porkhov
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | presidencia roque saenz pena
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | aykhal
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | verkhnyaya inta
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | tura
# Processing Record 13 of Set 1 | mackay
# Processing Record 14 of Set 1 | hami
# Processing Record 15 of Set 1 | marienburg
# Processing Record 16 of Set 1 | tual
# Processing Record 17 of Set 1 | ucluelet
# Processing Record 18 of Set 1 | camopi
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | wodonga
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | srivardhan
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | hofn
# Processing Record 25 of Set 1 | constitucion
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | burley
# Processing Record 28 of Set 1 | sembe
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | san patricio
# Processing Record 32 of Set 1 | sao filipe
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | fortuna
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | tarakan
# Processing Record 37 of Set 1 | kavaratti
# Processing Record 38 of Set 1 | dovers
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | hartford
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | ixtapa
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | padang
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 0 of Set 2 | kieta
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | nome
# Processing Record 3 of Set 2 | ksenyevka
# City not found. Skipping...
# Processing Record 4 of Set 2 | caravelas
# Processing Record 5 of Set 2 | maniitsoq
# Processing Record 6 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 7 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 2 | coquimbo
# Processing Record 9 of Set 2 | leh
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | bilibino
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | kuvshinovo
# Processing Record 15 of Set 2 | san javier
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | abu zabad
# Processing Record 18 of Set 2 | bafoulabe
# Processing Record 19 of Set 2 | benxi
# Processing Record 20 of Set 2 | soe
# Processing Record 21 of Set 2 | cienega
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | codrington
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 2 | comodoro rivadavia
# Processing Record 28 of Set 2 | chapais
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | torbay
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | juigalpa
# Processing Record 33 of Set 2 | bandarbeyla
# Processing Record 34 of Set 2 | kolondieba
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | iqaluit
# Processing Record 37 of Set 2 | canaries
# Processing Record 38 of Set 2 | gornopravdinsk
# Processing Record 39 of Set 2 | shimoda
# Processing Record 40 of Set 2 | lae
# Processing Record 41 of Set 2 | asau
# Processing Record 42 of Set 2 | treviglio
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | port hedland
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 2 | aklera
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | forestville
# Processing Record 0 of Set 3 | arman
# Processing Record 1 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 3 | parlakimidi
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | voloiac
# Processing Record 5 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 3 | umba
# Processing Record 7 of Set 3 | abashiri
# Processing Record 8 of Set 3 | tasiilaq
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | pevek
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | saint-pierre
# Processing Record 13 of Set 3 | kjopsvik
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | aasiaat
# Processing Record 16 of Set 3 | mecca
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | qasigiannguit
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | vila
# Processing Record 22 of Set 3 | batemans bay
# Processing Record 23 of Set 3 | hamadan
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | albany
# Processing Record 26 of Set 3 | copiapo
# Processing Record 27 of Set 3 | lavrentiya
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | manggar
# Processing Record 30 of Set 3 | cockburn town
# Processing Record 31 of Set 3 | cayenne
# Processing Record 32 of Set 3 | bambous virieux
# Processing Record 33 of Set 3 | hasaki
# Processing Record 34 of Set 3 | kasongo-lunda
# Processing Record 35 of Set 3 | nalut
# Processing Record 36 of Set 3 | qax
# Processing Record 37 of Set 3 | cardston
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | saint-augustin
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | flinders
# Processing Record 42 of Set 3 | aklavik
# Processing Record 43 of Set 3 | shirvan
# Processing Record 44 of Set 3 | maarianhamina
# Processing Record 45 of Set 3 | tomatlan
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | lamu
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | lorengau
# Processing Record 0 of Set 4 | nilai
# Processing Record 1 of Set 4 | kloulklubed
# Processing Record 2 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 4 | chicama
# Processing Record 4 of Set 4 | shahr-e babak
# Processing Record 5 of Set 4 | port macquarie
# Processing Record 6 of Set 4 | sumbe
# Processing Record 7 of Set 4 | kapit
# Processing Record 8 of Set 4 | zhoucheng
# Processing Record 9 of Set 4 | northam
# Processing Record 10 of Set 4 | saint-francois
# Processing Record 11 of Set 4 | arraial do cabo
# Processing Record 12 of Set 4 | lata
# Processing Record 13 of Set 4 | baker city
# Processing Record 14 of Set 4 | salalah
# Processing Record 15 of Set 4 | sitka
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | upernavik
# Processing Record 18 of Set 4 | cabo san lucas
# Processing Record 19 of Set 4 | saint-felicien
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | kaitangata
# Processing Record 22 of Set 4 | san carlos de bariloche
# Processing Record 23 of Set 4 | narsaq
# Processing Record 24 of Set 4 | aguimes
# Processing Record 25 of Set 4 | sekoma
# Processing Record 26 of Set 4 | sorland
# Processing Record 27 of Set 4 | lazurne
# Processing Record 28 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 4 | kyrylivka
# Processing Record 30 of Set 4 | swellendam
# Processing Record 31 of Set 4 | esperance
# Processing Record 32 of Set 4 | torrington
# Processing Record 33 of Set 4 | barrow
# Processing Record 34 of Set 4 | zhangjiakou
# Processing Record 35 of Set 4 | sotouboua
# Processing Record 36 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 4 | chippewa falls
# Processing Record 38 of Set 4 | pundaguitan
# Processing Record 39 of Set 4 | urengoy
# Processing Record 40 of Set 4 | pechenga
# Processing Record 41 of Set 4 | korgen
# Processing Record 42 of Set 4 | kalmunai
# Processing Record 43 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 4 | lena
# Processing Record 45 of Set 4 | ternate
# Processing Record 46 of Set 4 | pisco
# Processing Record 47 of Set 4 | kuching
# Processing Record 48 of Set 4 | manwath
# City not found. Skipping...
# Processing Record 49 of Set 4 | tezu
# Processing Record 0 of Set 5 | vila velha
# Processing Record 1 of Set 5 | besikduzu
# Processing Record 2 of Set 5 | east london
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | cidreira
# Processing Record 5 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 5 | vieux-habitants
# Processing Record 7 of Set 5 | luena
# Processing Record 8 of Set 5 | kazanskaya
# Processing Record 9 of Set 5 | presidente epitacio
# Processing Record 10 of Set 5 | port-cartier
# Processing Record 11 of Set 5 | linchuan
# City not found. Skipping...
# Processing Record 12 of Set 5 | verkhoyansk
# Processing Record 13 of Set 5 | umm lajj
# Processing Record 14 of Set 5 | bengkulu
# Processing Record 15 of Set 5 | bilma
# Processing Record 16 of Set 5 | grindavik
# Processing Record 17 of Set 5 | noumea
# Processing Record 18 of Set 5 | nha trang
# Processing Record 19 of Set 5 | flin flon
# Processing Record 20 of Set 5 | saint-georges
# Processing Record 21 of Set 5 | saint george
# Processing Record 22 of Set 5 | paita
# Processing Record 23 of Set 5 | clyde river
# Processing Record 24 of Set 5 | kalemie
# Processing Record 25 of Set 5 | los llanos de aridane
# Processing Record 26 of Set 5 | roma
# Processing Record 27 of Set 5 | mahibadhoo
# Processing Record 28 of Set 5 | port hardy
# Processing Record 29 of Set 5 | tautira
# Processing Record 30 of Set 5 | chivay
# Processing Record 31 of Set 5 | baglung
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | quzhou
# Processing Record 34 of Set 5 | mandurah
# Processing Record 35 of Set 5 | hambantota
# Processing Record 36 of Set 5 | tilichiki
# Processing Record 37 of Set 5 | talnakh
# Processing Record 38 of Set 5 | grand gaube
# Processing Record 39 of Set 5 | evanston
# Processing Record 40 of Set 5 | paramonga
# Processing Record 41 of Set 5 | stuttgart
# Processing Record 42 of Set 5 | pacific grove
# Processing Record 43 of Set 5 | kasongo
# Processing Record 44 of Set 5 | thayetmyo
# Processing Record 45 of Set 5 | bougouni
# Processing Record 46 of Set 5 | yulara
# Processing Record 47 of Set 5 | axim
# Processing Record 48 of Set 5 | parkes
# Processing Record 49 of Set 5 | ribeira grande
# Processing Record 0 of Set 6 | margate
# Processing Record 1 of Set 6 | vardo
# Processing Record 2 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 4 of Set 6 | qarchi gak
# Processing Record 5 of Set 6 | alice springs
# Processing Record 6 of Set 6 | belogorsk
# Processing Record 7 of Set 6 | tagusao
# Processing Record 8 of Set 6 | bethel
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | pangnirtung
# Processing Record 11 of Set 6 | san lawrenz
# Processing Record 12 of Set 6 | port-gentil
# Processing Record 13 of Set 6 | san benito
# Processing Record 14 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 6 | lubao
# Processing Record 16 of Set 6 | daru
# Processing Record 17 of Set 6 | oranjemund
# Processing Record 18 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 19 of Set 6 | sarkand
# Processing Record 20 of Set 6 | kazachinskoye
# Processing Record 21 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 6 | vila praia de ancora
# Processing Record 23 of Set 6 | smithers
# Processing Record 24 of Set 6 | linxia
# Processing Record 25 of Set 6 | waingapu
# Processing Record 26 of Set 6 | pinega
# Processing Record 27 of Set 6 | vao
# Processing Record 28 of Set 6 | basco
# Processing Record 29 of Set 6 | mehamn
# Processing Record 30 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 6 | ketchikan
# Processing Record 32 of Set 6 | lagoa
# Processing Record 33 of Set 6 | bontang
# Processing Record 34 of Set 6 | lander
# Processing Record 35 of Set 6 | sao paulo de olivenca
# Processing Record 36 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 6 | pingliang
# Processing Record 39 of Set 6 | tiarei
# Processing Record 40 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 41 of Set 6 | alpena
# Processing Record 42 of Set 6 | spornoye
# Processing Record 43 of Set 6 | socorro
# Processing Record 44 of Set 6 | gardan diwal
# City not found. Skipping...
# Processing Record 45 of Set 6 | talcahuano
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | puerto suarez
# Processing Record 48 of Set 6 | deputatskiy
# Processing Record 49 of Set 6 | airai
# Processing Record 0 of Set 7 | lagos
# Processing Record 1 of Set 7 | moroceli
# Processing Record 2 of Set 7 | puerto ayacucho
# Processing Record 3 of Set 7 | regeneracao
# Processing Record 4 of Set 7 | necochea
# Processing Record 5 of Set 7 | portland
# Processing Record 6 of Set 7 | xichang
# Processing Record 7 of Set 7 | shelburne
# Processing Record 8 of Set 7 | yakeshi
# Processing Record 9 of Set 7 | auki
# Processing Record 10 of Set 7 | gallipoli
# Processing Record 11 of Set 7 | mareeba
# Processing Record 12 of Set 7 | shingu
# Processing Record 13 of Set 7 | fenyi
# Processing Record 14 of Set 7 | otane
# Processing Record 15 of Set 7 | mokhsogollokh
# Processing Record 16 of Set 7 | bayan
# Processing Record 17 of Set 7 | ilulissat
# Processing Record 18 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 19 of Set 7 | nola
# Processing Record 20 of Set 7 | kahului
# Processing Record 21 of Set 7 | topchanchi
# Processing Record 22 of Set 7 | goderich
# Processing Record 23 of Set 7 | provideniya
# Processing Record 24 of Set 7 | cosala
# Processing Record 25 of Set 7 | khabary
# Processing Record 26 of Set 7 | zhigansk
# Processing Record 27 of Set 7 | naze
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | baiyin
# Processing Record 30 of Set 7 | ostrovnoy
# Processing Record 31 of Set 7 | nelson bay
# Processing Record 32 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 7 | geraldton
# Processing Record 34 of Set 7 | nanortalik
# Processing Record 35 of Set 7 | curanilahue
# Processing Record 36 of Set 7 | malpe
# Processing Record 37 of Set 7 | sinnamary
# Processing Record 38 of Set 7 | katsuura
# Processing Record 39 of Set 7 | te anau
# Processing Record 40 of Set 7 | russell
# Processing Record 41 of Set 7 | pathein
# Processing Record 42 of Set 7 | mabaruma
# Processing Record 43 of Set 7 | singaraja
# Processing Record 44 of Set 7 | wexford
# Processing Record 45 of Set 7 | mollendo
# Processing Record 46 of Set 7 | camabatela
# Processing Record 47 of Set 7 | cap malheureux
# Processing Record 48 of Set 7 | monster
# Processing Record 49 of Set 7 | sola
# Processing Record 0 of Set 8 | saint-leu
# Processing Record 1 of Set 8 | broome
# Processing Record 2 of Set 8 | redcliffe
# Processing Record 3 of Set 8 | yar-sale
# Processing Record 4 of Set 8 | husavik
# Processing Record 5 of Set 8 | road town
# Processing Record 6 of Set 8 | moba
# Processing Record 7 of Set 8 | brae
# Processing Record 8 of Set 8 | manokwari
# Processing Record 9 of Set 8 | merauke
# Processing Record 10 of Set 8 | abu samrah
# Processing Record 11 of Set 8 | tiksi
# Processing Record 12 of Set 8 | shangzhi

# %%
# convert data to df
city_data_pd = pd.DataFrame(city_data)

# show counts
city_data_pd.count()

# %%
# Display the City Data Frame
city_data_pd.head()

# %%
city_data_pd.describe()

# %%
#  get cities with humidity over 100%
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index
                                  
dirty_city_data

# %%
# new df
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()

# %%
# extract data
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# export into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-55, 90))

# %% [markdown]
# The high r value indicates a strong positive correlation between latitude and max temperature. R values ~ 0.5 indicate that there is a moderate positive correlation.

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-50, 20))

# %% [markdown]
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))

# %% [markdown]
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-50, 20))

# %% [markdown]
# The low r values indicate that there is no real relationship between wind speed and latitude." The difference between the hemispheres doesn't seem to be significant enough to comment upon.
